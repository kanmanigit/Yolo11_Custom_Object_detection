# %%
from ultralytics import YOLO

# %%
#Load a pretrained_model
model = YOLO("yolo11n.pt")

#Train the model 

results =model.train(
           data="/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/LicensePlateDataset/data.yaml", #path to dataset.yaml
           epochs=5,  # number of training epochs
           imgsz=640, # training image size
           device='cpu')  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.51 🚀 Python-3.10.16 torch-2.5.1 CPU (Apple M2)
# ...

# %%
# Perform Object detection on image

from ultralytics import YOLO

#Load the bestfit.pt model
model = YOLO('/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/LicensePlateDataset/runs/detect/train17/weights/best.pt')

#making the Predictions on the image
result= model("/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/0.jpg")
result[0].show()
# Out:
# image 1/1 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/0.jpg: 448x640 1 License_Plate, 56.0ms
# Speed: 6.5ms preprocess, 56.0ms inference, 7.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Perform Object detection on image 

from ultralytics import YOLO
#Load the bestfit.pt model
model = YOLO('/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/LicensePlateDataset/runs/detect/train17/weights/best.pt')

#making the Predictions on the images og the test_images folder  
result= model("/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images",save=True)
result[0].show()
# Out:
# image 1/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/0.jpg: 448x640 1 License_Plate, 47.4ms
# image 2/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/1.jpg: 384x640 1 License_Plate, 36.7ms
# image 3/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/10.jpg: 640x512 1 License_Plate, 42.4ms
# image 4/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/11.jpg: 640x512 1 License_Plate, 48.9ms
# image 5/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/12.jpg: 448x640 (no detections), 35.2ms
# image 6/12 /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_images/2.jpg: 480x640 3 License_Plates, 43.9ms
# ...

# %%
#Perform Obeject detections on the images of the test_videos folder

#Load the bestfit.pt model
model = YOLO('/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/LicensePlateDataset/runs/detect/train17/weights/best.pt')

#making the Predictions on the images of the test_images folder  
result= model("/Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_videos",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/3 (frame 1/450) /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_videos/1.mp4: 384x640 (no detections), 33.1ms
# video 1/3 (frame 2/450) /Users/kanmaniramasamy/Documents/HopeAI_Tamil/yolo11/Yolo11_Custom_Object_detection/test_videos/1.mp4: 384x640 (no detections), 61.4ms
# ...
